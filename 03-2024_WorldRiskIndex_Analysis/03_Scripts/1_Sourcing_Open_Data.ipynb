# %% [markdown]
# # Sourcing open data
#
# #### Table of Contents
#
#     1. Importing libraries
#     2. Importing data
#     3. Consistency checks & cleaning
#         3.1 Renaming columns
#         3.2 Missing values
#         3.3 Unifying 'Country' values
#         3.4 Data types
#             Check for mixed-type values
#             Change data types to reduce size
#         3.5 Duplicates
#     4. Descriptive statistics
#     5. Exporting data

# %% [markdown]
# # 1. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing data

# %%
# Turn project folder path into a string
path = r'/Users/sarahtischer/Desktop/CareerFoundry/Data Immersion/Achievement 6/03-2024_WorldRiskIndex_Analysis'

# %%
# Import "WRI_Kaggle.csv"
df = pd.read_csv(os.path.join(path, '02_Data', 'Original_data', 'WRI_Kaggle.csv'), index_col = False)

# %%
# Confirm the shape of the dataset
df.shape
# Out:
# (1917, 12)

# %% [markdown]
# # 3. Consistency checks & cleaning

# %%
# Check the metadata of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Region                        1917 non-null   object
#  1   WRI                           1917 non-null   float64
#  2   Exposure                      1917 non-null   float64
#  3   Vulnerability                 1917 non-null   float64
#  4   Susceptibility                1917 non-null   float64
#  5   Lack of Coping Capabilities   1917 non-null   float64
#  6    Lack of Adaptive Capacities  1916 non-null   float64
#  7   Year                          1917 non-null   int64
#  8   Exposure Category             1917 non-null   object
#  9   WRI Category                  1916 non-null   object
#  10  Vulnerability Category        1913 non-null   object
#  11  Susceptibility Category       1917 non-null   object
# dtypes: float64(6), int64(1), object(5)
# memory usage: 179.8+ KB

# %% [markdown]
# ## 3.1 Renaming columns

# %%
# Rename columns for the sake of consistency
df.rename(
    columns = {
        'Region' : 'Country', 
        'Lack of Coping Capabilities' : 'Lack of Coping Capacities', 
        ' Lack of Adaptive Capacities' : 'Lack of Adaptive Capacities'
    }, inplace = True
)

# %%
# Change order of columns for a more intuitive view

# Define the desired order of columns
column_order = [
    'Country', 'Year', 'WRI', 'Exposure', 'Vulnerability', 
    'Susceptibility', 'Lack of Coping Capacities', 'Lack of Adaptive Capacities',
    'WRI Category', 'Exposure Category', 'Vulnerability Category', 'Susceptibility Category'
]

# Reorder columns in DataFrame
df = df[column_order]

# %%
# Check the output
df.head()
# Out:
#        Country  Year    WRI  Exposure  Vulnerability  Susceptibility  \
# 0      Vanuatu  2011  32.00     56.33          56.81           37.14
# 1        Tonga  2011  29.08     56.04          51.90           28.94
# 2  Philippinen  2011  24.32     45.09          53.93           34.99
# 3    Salomonen  2011  23.51     36.40          64.60           44.11
# 4    Guatemala  2011  20.88     38.42          54.35           35.36
#
#    Lack of Coping Capacities  Lack of Adaptive Capacities WRI Category  \
# 0                      79.34                        53.96    Very High
# 1                      81.80                        44.97    Very High
# 2                      82.78                        44.01    Very High
# 3                      85.95                        63.74    Very High
# 4                      77.83                        49.87    Very High
#
#   Exposure Category Vulnerability Category Susceptibility Category
# 0         Very High                   High                    High
# 1         Very High                 Medium                  Medium
# 2         Very High                   High                    High
# 3         Very High              Very High                    High
# 4         Very High                   High                    High

# %% [markdown]
# ## 3.2 Missing values

# %%
# Find missing values
df.isnull().sum()
# Out:
# Country                        0
# Year                           0
# WRI                            0
# Exposure                       0
# Vulnerability                  0
# Susceptibility                 0
# Lack of Coping Capacities      0
# Lack of Adaptive Capacities    1
# WRI Category                   1
# Exposure Category              0
# Vulnerability Category         4
# Susceptibility Category        0
# dtype: int64

# %%
# Create subset of missing observations
df_nan = df[df[['Lack of Adaptive Capacities', 'WRI Category', 'Vulnerability Category']].isnull().any(axis=1)]

df_nan
# Out:
#                           Country  Year    WRI  Exposure  Vulnerability  \
# 1193                   Österreich  2019   2.87     13.18          21.75
# 1202                  Deutschland  2019   2.43     11.51          21.11
# 1205                     Norwegen  2019   2.34     10.60          22.06
# 1292  Föd. Staaten v. Mikronesien  2020   7.59     14.95          50.77
# 1858       Korea Republic of 4.59  2016  14.89     30.82          14.31
#
#       Susceptibility  Lack of Coping Capacities  Lack of Adaptive Capacities  \
# 1193           13.63                      39.27                        12.34
# 1202           14.30                      36.44                        12.60
# 1205           13.29                      39.21                        13.68
# 1292           31.79                      72.13                        48.39
# 1858           46.55                      31.59                          NaN
#
#      WRI Category Exposure Category Vulnerability Category  \
# 1193     Very Low            Medium                    NaN
# 1202     Very Low               Low                    NaN
# 1205     Very Low               Low                    NaN
# 1292          NaN              High                   High
# 1858    Very High         Very High                    NaN
#
#      Susceptibility Category
# 1193                Very Low
# 1202                Very Low
# 1205                Very Low
# 1292                    High
# 1858                    High

# %%
# Set the missing values as obtained from orginal reports
df.loc[1193, 'Vulnerability Category'] = 'Very Low'
df.loc[1202, 'Vulnerability Category'] = 'Very Low'
df.loc[1205, 'Vulnerability Category'] = 'Very Low'
df.loc[1292, 'WRI Category'] = 'High'

# %%
# Correct apparently misplaced columns of row index 1858 (data obtained from original report)

# Specify the new values for each field
new_values = {
    'Country': 'Republic of Korea',
    'WRI': 4.59,
    'Exposure': 14.89,
    'Vulnerability': 30.82,
    'Susceptibility': 14.31,
    'Lack of Coping Capacities': 46.55,
    'Lack of Adaptive Capacities': 31.59,
    'Exposure Category': 'High',
    'WRI Category': 'Low',
    'Vulnerability Category': 'Very Low',
    'Susceptibility Category': 'Very Low'
}

# Update the values for the specified row
df.loc[1858, list(new_values.keys())] = list(new_values.values())

# %%
# Check the output of all changed rows
print(df.iloc[[1193, 1202, 1205, 1292, 1858]])
# Out:
#                           Country  Year   WRI  Exposure  Vulnerability  \
# 1193                   Österreich  2019  2.87     13.18          21.75
# 1202                  Deutschland  2019  2.43     11.51          21.11
# 1205                     Norwegen  2019  2.34     10.60          22.06
# 1292  Föd. Staaten v. Mikronesien  2020  7.59     14.95          50.77
# 1858            Republic of Korea  2016  4.59     14.89          30.82
#
#       Susceptibility  Lack of Coping Capacities  Lack of Adaptive Capacities  \
# 1193           13.63                      39.27                        12.34
# 1202           14.30                      36.44                        12.60
# 1205           13.29                      39.21                        13.68
# 1292           31.79                      72.13                        48.39
# 1858           14.31                      46.55                        31.59
#
#      WRI Category Exposure Category Vulnerability Category  \
# 1193     Very Low            Medium               Very Low
# 1202     Very Low               Low               Very Low
# 1205     Very Low               Low               Very Low
# 1292         High              High                   High
# 1858          Low              High               Very Low
#
#      Susceptibility Category
# 1193                Very Low
# 1202                Very Low
# 1205                Very Low
# 1292                    High
# 1858                Very Low

# %%
# Check for missing values again
df.isnull().sum()
# Out:
# Country                        0
# Year                           0
# WRI                            0
# Exposure                       0
# Vulnerability                  0
# Susceptibility                 0
# Lack of Coping Capacities      0
# Lack of Adaptive Capacities    0
# WRI Category                   0
# Exposure Category              0
# Vulnerability Category         0
# Susceptibility Category        0
# dtype: int64

# %% [markdown]
# ## 3.3 Unifying 'Country' values

# %%
# Clear display options
pd.options.display.max_rows = None

# %%
# Find frequencies of countries
df['Country'].value_counts(dropna = False)
# Out:
# Country
# Vanuatu                             11
# Lesotho                             11
# Turkmenistan                        11
# Eritrea                             11
# Peru                                11
# Uganda                              11
# Panama                              11
# Pakistan                            11
# Sri Lanka                           11
# Angola                              11
# Malaysia                            11
# Myanmar                             11
# Ecuador                             11
# Malawi                              11
# Guyana                              11
# Nigeria                             11
# Liberia                             11
# Sudan                               11
# Thailand                            11
# Namibia                             11
# Guinea                              11
# Ukraine                             11
# Malta                               11
# Bahrain                             11
# Kiribati                            11
# Grenada                             11
# Barbados                            11
# Israel                              11
# Tonga                               11
# Portugal                            11
# China                               11
# Kuwait                              11
# Uruguay                             11
# Paraguay                            11
# Bahamas                             11
# Belize                              11
# Venezuela                           11
# Nepal                               11
# Ghana                               11
# Oman                                11
# Gambia                              11
# Timor-Leste                         11
# Mali                                11
# Burkina Faso                        11
# Niger                               11
# Bhutan                              11
# Costa Rica                          11
# Haiti                               11
# Brunei Darussalam                   11
# Senegal                             11
# Sierra Leone                        11
# Japan                               11
# Burundi                             11
# Mauritius                           11
# Benin                               11
# Togo                                11
# El Salvador                         11
# Afghanistan                         11
# Chile                               11
# Guinea-Bissau                       11
# Honduras                            11
# Guatemala                           11
# Nicaragua                           11
# Iran                                10
# Botswana                            10
# Südkorea                             9
# Tschechische Republik                9
# Papua-Neuguinea                      9
# Libanon                              9
# Kroatien                             9
# Philippinen                          9
# Slowenien                            9
# Katar                                9
# Argentinien                          9
# Italien                              9
# Madagaskar                           9
# Australien                           9
# Neuseeland                           9
# Kasachstan                           9
# Brasilien                            9
# Bulgarien                            9
# Simbabwe                             9
# Irland                               9
# Libyen                               9
# Mauretanien                          9
# Vereinigtes Königreich               9
# Kambodscha                           9
# Schweden                             9
# Finnland                             9
# Estland                              9
# Norwegen                             9
# Bangladesch                          9
# Ägypten                              9
# Schweiz                              9
# Kanada                               9
# Seychellen                           9
# Luxemburg                            9
# Frankreich                           9
# Singapur                             9
# Russische Föderation                 9
# Dänemark                             9
# Litauen                              9
# Deutschland                          9
# Saudi-Arabien                        9
# Lettland                             9
# Spanien                              9
# Jordanien                            9
# Österreich                           9
# Polen                                9
# Zypern                               9
# Belgien                              9
# Slowakei                             9
# Irak                                 9
# Bolivien                             9
# Georgien                             9
# Türkei                               9
# Griechenland                         9
# Marokko                              9
# Dominikanische Republik              9
# Tadschikistan                        9
# Indien                               9
# Niederlande                          9
# Kongo                                9
# Kenia                                9
# Indonesien                           9
# Algerien                             9
# Äthiopien                            9
# Sambia                               9
# Kirgisistan                          9
# Tansania                             9
# Ruanda                               9
# Vietnam                              9
# Elfenbeinküste                       9
# Kamerun                              9
# Albanien                             9
# Usbekistan                           9
# Kap Verde                            9
# Mosambik                             9
# Dschibuti                            9
# Salomonen                            9
# Komoren                              9
# Armenien                             9
# Serbien                              9
# Ungarn                               9
# Südafrika                            9
# Tunesien                             9
# Island                               9
# Laos                                 9
# Kuba                                 9
# Syrien                               9
# Bosnien und Herzegowina              9
# Gabun                                9
# Fidschi                              9
# Mexiko                               9
# Jamaika                              9
# Trinidad und Tobago                  9
# Äquatorialguinea                     9
# Aserbaidschan                        9
# Jemen                                9
# Kolumbien                            9
# Tschad                               9
# Rumänien                             8
# Swasiland                            8
# Zentralafrikanische Republik         8
# Moldawien                            8
# Mongolei                             8
# Samoa                                7
# Weißrussland                         7
# Vereinigte Arabische Emirate         7
# Surinam                              6
# Mazedonien                           6
# Suriname                             5
# Belarus                              4
# Ver. Staaten von Amerika             4
# Vereinigte Staaten v. A.             3
# Antigua und Barbuda                  3
# Montenegro                           3
# Nordmazedonien                       3
# Demokratische Rep. Kongo             3
# St. Lucia                            3
# São Tomé and Príncipe                3
# Malediven                            3
# São Tomé und Príncipe                3
# United Kingdom                       2
# New Zealand                          2
# Slovakia                             2
# Austria                              2
# Slovenia                             2
# Argentina                            2
# Kazakhstan                           2
# Russia                               2
# United States                        2
# Australia                            2
# Libyan Arab Jamahiriya               2
# Jordan                               2
# Bulgaria                             2
# Croatia                              2
# Brazil                               2
# Italy                                2
# Ireland                              2
# Equatorial Guinea                    2
# Latvia                               2
# Iraq                                 2
# Republic of Moldova                  2
# Bolivia                              2
# Turkey                               2
# Czech Republic                       2
# Germany                              2
# Belgium                              2
# Poland                               2
# Föd. Staaten von Mikronesien         2
# Dominica                             2
# Qatar                                2
# Saudi Arabia                         2
# Iceland                              2
# United Arab Emirates                 2
# Sweden                               2
# Finland                              2
# Singapore                            2
# Egypt                                2
# Norway                               2
# Estonia                              2
# Switzerland                          2
# Seychelles                           2
# Luxembourg                           2
# France                               2
# Cyprus                               2
# Denmark                              2
# Mongolia                             2
# Hungary                              2
# Lithuania                            2
# Canada                               2
# Spain                                2
# South Africa                         2
# Lebanon                              2
# Tunisia                              2
# Algeria                              2
# United Republic of Tanzania          2
# Mauritania                           2
# Netherlands                          2
# Kyrgyzstan                           2
# Uzbekistan                           2
# Syrian Arab Republic                 2
# Cote d'Ivoire                        2
# Djibouti                             2
# Zimbabwe                             2
# Albania                              2
# Cape Verde                           2
# Indonesia                            2
# Madagascar                           2
# Cameroon                             2
# Chad                                 2
# Dominican Republic                   2
# Jamaica                              2
# Viet Nam                             2
# Fiji                                 2
# Papua New Guinea                     2
# Cambodia                             2
# Solomon Islands                      2
# Bangladesh                           2
# Philippines                          2
# Vereinigte Staaten von Amerika       2
# Swaziland                            2
# Mozambique                           2
# Zambia                               2
# Morocco                              2
# Azerbaijan                           2
# Yemen                                2
# Ethiopia                             2
# Bosnia and Herzegovina               2
# Armenia                              2
# Gabon                                2
# Mexico                               2
# Romania                              2
# Central African Republic             2
# Georgia                              2
# Cuba                                 2
# Colombia                             2
# Kenya                                2
# India                                2
# Greece                               2
# Tajikistan                           2
# Rwanda                               2
# Comoros                              2
# Serbia                               2
# Trinidad and Tobago                  2
# Congo                                2
# Mongolien                            1
# Föd. Staaten v. Mikronesien          1
# St. Vincent u. d. Grenadinen         1
# Romänien                             1
# Iran (Islamic Republic of)           1
# Republic of Macedonia                1
# Lao People's Democ. Republic         1
# St. Vincent u. die Grenadinen        1
# St. Vincent und d. Grenadinen        1
# Korea Republic of                    1
# Vereinigte Arabisch Emirate          1
# Moldau                               1
# Botsuana                             1
# Lao People's Democratic Republic     1
# Zentralafrik. Republik               1
# Ver. Arabische Emirate               1
# Eswatini                             1
# T. f. Yugo. Rep. of Macedonia        1
# Republic of Korea                    1
# Name: count, dtype: int64

# %%
# Define a mapping dictionary to replace inconsistent country names with their official ones as of 2023
mapping_dict = {
    'Albanien': 'Albania',
    'Algerien': 'Algeria',
    'Antigua und Barbuda': 'Antigua and Barbuda',
    'Argentinien': 'Argentina',
    'Armenien': 'Armenia',
    'Australien': 'Australia',
    'Österreich': 'Austria',
    'Aserbaidschan': 'Azerbaijan',
    'Bangladesch': 'Bangladesh',
    'Weißrussland': 'Belarus',
    'Belgien': 'Belgium',
    'Venezuela': 'Bolivarian Republic of Venezuela',
    'Bosnien und Herzegowina': 'Bosnia and Herzegovina',
    'Botsuana': 'Botswana',
    'Brasilien': 'Brazil',
    'Bulgarien': 'Bulgaria',
    'Kambodscha': 'Cambodia',
    'Kamerun': 'Cameroon',
    'Kanada': 'Canada',
    'Kap Verde': 'Cape Verde',
    'Zentralafrikanische Republik': 'Central African Republic',
    'Zentralafrik. Republik': 'Central African Republic',
    'Tschad': 'Chad',
    'Kolumbien': 'Colombia',
    'Komoren': 'Comoros',
    'Elfenbeinküste': 'Cote d\'Ivoire',
    'Kroatien': 'Croatia',
    'Kuba': 'Cuba',
    'Zypern': 'Cyprus',
    'Tschechische Republik': 'Czech Republic',
    'Demokratische Rep. Kongo': 'Democratic Republic of Congo',
    'Dänemark': 'Denmark',
    'Dschibuti': 'Djibouti',
    'Dominikanische Republik': 'Dominican Republic',
    'Ägypten': 'Egypt',
    'Äquatorialguinea': 'Equatorial Guinea',
    'Estland': 'Estonia',
    'Swasiland': 'Eswatini',
    'Swaziland': 'Eswatini',
    'Äthiopien': 'Ethiopia',
    'Föd. Staaten von Mikronesien': 'Federated States of Micronesia',
    'Föd. Staaten v. Mikronesien': 'Federated States of Micronesia',
    'Fidschi': 'Fiji',
    'Finnland': 'Finland',
    'Frankreich': 'France',
    'Gabun': 'Gabon',
    'Georgien': 'Georgia',
    'Deutschland': 'Germany',
    'Griechenland': 'Greece',
    'Ungarn': 'Hungary',
    'Island': 'Iceland',
    'Indien': 'India',
    'Indonesien': 'Indonesia',
    'Iran': 'Iran (Islamic Republic of)',
    'Irak': 'Iraq',
    'Irland': 'Ireland',
    'Italien': 'Italy',
    'Jamaika': 'Jamaica',
    'Jordanien': 'Jordan',
    'Kasachstan': 'Kazakhstan',
    'Kenia': 'Kenya',
    'Kirgisistan': 'Kyrgyzstan',
    'Laos': 'Lao People\'s Democratic Republic',
    'Lao People\'s Democ. Republic': 'Lao People\'s Democratic Republic',
    'Lettland': 'Latvia',
    'Libanon': 'Lebanon',
    'Libya': 'Libyan Arab Jamahiriya',
    'Libyen': 'Libyan Arab Jamahiriya',
    'Litauen': 'Lithuania',
    'Luxemburg': 'Luxembourg',
    'Madagaskar': 'Madagascar',
    'Malediven': 'Maldives',
    'Mauretanien': 'Mauritania',
    'Mexiko': 'Mexico',
    'Mongolei': 'Mongolia',
    'Mongolien': 'Mongolia',
    'Marokko': 'Morocco',
    'Mosambik': 'Mozambique',
    'Niederlande': 'Netherlands',
    'Neuseeland': 'New Zealand',
    'Republic of Macedonia': 'North Macedonia',
    'T. f. Yugo. Rep. of Macedonia': 'North Macedonia',
    'Mazedonien': 'North Macedonia',
    'Nordmazedonien': 'North Macedonia',
    'Norwegen': 'Norway',
    'Papua-Neuguinea': 'Papua New Guinea',
    'Philippinen': 'Philippines',
    'Bolivien': 'Plurinational State of Bolivia',
    'Bolivia': 'Plurinational State of Bolivia',
    'Polen': 'Poland',
    'Katar': 'Qatar',
    'Kongo': 'Republic of Congo',
    'Congo': 'Republic of Congo',
    'Südkorea': 'Republic of Korea',
    'South Korea': 'Republic of Korea',
    'Korea Republic of': 'Republic of Korea',
    'Moldawien': 'Republic of Moldova',
    'Moldau': 'Republic of Moldova',
    'Romänien': 'Romania',
    'Rumänien': 'Romania',
    'Russische Föderation': 'Russian Federation',
    'Russia': 'Russian Federation',
    'Ruanda': 'Rwanda',
    'St. Lucia': 'Saint Lucia',
    'St. Vincent und d. Grenadinen': 'Saint Vincent and the Grenadines',
    'St. Vincent u. d. Grenadinen': 'Saint Vincent and the Grenadines',
    'St. Vincent u. die Grenadinen': 'Saint Vincent and the Grenadines',
    'São Tomé and Príncipe': 'Sao Tome and Principe',
    'São Tomé und Príncipe': 'Sao Tome and Principe',
    'Saudi-Arabien': 'Saudi Arabia',
    'Serbien': 'Serbia',
    'Seychellen': 'Seychelles',
    'Singapur': 'Singapore',
    'Slowakei': 'Slovakia',
    'Slowenien': 'Slovenia',
    'Salomonen': 'Solomon Islands',
    'Südafrika': 'South Africa',
    'Spanien': 'Spain',
    'Surinam': 'Suriname',
    'Schweden': 'Sweden',
    'Schweiz': 'Switzerland',
    'Syria': 'Syrian Arab Republic',
    'Syrien': 'Syrian Arab Republic',
    'Tadschikistan': 'Tajikistan',
    'Trinidad und Tobago': 'Trinidad and Tobago',
    'Tunesien': 'Tunisia',
    'Türkei': 'Turkey',
    'Vereinigte Arabische Emirate': 'United Arab Emirates',
    'Vereinigte Arabisch Emirate': 'United Arab Emirates',
    'Ver. Arabische Emirate': 'United Arab Emirates',
    'Vereinigtes Königreich': 'United Kingdom of Great Britain and Northern Ireland',
    'United Kingdom': 'United Kingdom of Great Britain and Northern Ireland',
    'Tanzania': 'United Republic of Tanzania',
    'Tansania': 'United Republic of Tanzania',
    'Ver. Staaten von Amerika': 'United States of America',
    'Vereinigte Staaten v. A.': 'United States of America',
    'United States': 'United States of America',
    'Vereinigte Staaten von Amerika': 'United States of America',
    'Usbekistan': 'Uzbekistan',
    'Vietnam': 'Viet Nam',
    'Jemen': 'Yemen',
    'Sambia': 'Zambia',
    'Simbabwe': 'Zimbabwe'
}

# Replace inconsistent values with their English equivalents
df['Country'] = df['Country'].replace(mapping_dict)

# %%
# Find frequencies of countries
df['Country'].value_counts(dropna = False)
# Out:
# Country
# Vanuatu                                                 11
# New Zealand                                             11
# Plurinational State of Bolivia                          11
# Jordan                                                  11
# Iran (Islamic Republic of)                              11
# Lebanon                                                 11
# Republic of Moldova                                     11
# Italy                                                   11
# Bahamas                                                 11
# Australia                                               11
# Brazil                                                  11
# Serbia                                                  11
# Ireland                                                 11
# Czech Republic                                          11
# Republic of Korea                                       11
# Paraguay                                                11
# United Arab Emirates                                    11
# Bulgaria                                                11
# Kazakhstan                                              11
# Uruguay                                                 11
# Turkey                                                  11
# Hungary                                                 11
# Azerbaijan                                              11
# Syrian Arab Republic                                    11
# Trinidad and Tobago                                     11
# Tonga                                                   11
# Namibia                                                 11
# Mexico                                                  11
# Romania                                                 11
# China                                                   11
# Gabon                                                   11
# Bosnia and Herzegovina                                  11
# Nepal                                                   11
# Botswana                                                11
# Bolivarian Republic of Venezuela                        11
# Cuba                                                    11
# Belize                                                  11
# North Macedonia                                         11
# Lao People's Democratic Republic                        11
# Iraq                                                    11
# Tunisia                                                 11
# South Africa                                            11
# Argentina                                               11
# Slovenia                                                11
# United States of America                                11
# Norway                                                  11
# Luxembourg                                              11
# Seychelles                                              11
# Israel                                                  11
# Canada                                                  11
# Switzerland                                             11
# Barbados                                                11
# Egypt                                                   11
# Grenada                                                 11
# Estonia                                                 11
# Croatia                                                 11
# Finland                                                 11
# Sweden                                                  11
# Kiribati                                                11
# Bahrain                                                 11
# Iceland                                                 11
# Saudi Arabia                                            11
# Malta                                                   11
# Qatar                                                   11
# France                                                  11
# Oman                                                    11
# Singapore                                               11
# Denmark                                                 11
# Kuwait                                                  11
# Libyan Arab Jamahiriya                                  11
# Portugal                                                11
# United Kingdom of Great Britain and Northern Ireland    11
# Russian Federation                                      11
# Belgium                                                 11
# Cyprus                                                  11
# Mongolia                                                11
# Poland                                                  11
# Austria                                                 11
# Slovakia                                                11
# Spain                                                   11
# Latvia                                                  11
# Ukraine                                                 11
# Belarus                                                 11
# Germany                                                 11
# Lithuania                                               11
# Equatorial Guinea                                       11
# Malaysia                                                11
# Yemen                                                   11
# Sierra Leone                                            11
# Chile                                                   11
# Mauritius                                               11
# Senegal                                                 11
# Indonesia                                               11
# Burkina Faso                                            11
# Burundi                                                 11
# Mali                                                    11
# Haiti                                                   11
# Viet Nam                                                11
# Honduras                                                11
# Japan                                                   11
# Benin                                                   11
# Togo                                                    11
# Cameroon                                                11
# Albania                                                 11
# Mozambique                                              11
# Colombia                                                11
# Zimbabwe                                                11
# Dominican Republic                                      11
# Chad                                                    11
# Cape Verde                                              11
# Nicaragua                                               11
# Philippines                                             11
# Solomon Islands                                         11
# Guatemala                                               11
# Bangladesh                                              11
# Timor-Leste                                             11
# Costa Rica                                              11
# Cambodia                                                11
# El Salvador                                             11
# Papua New Guinea                                        11
# Jamaica                                                 11
# Madagascar                                              11
# Brunei Darussalam                                       11
# Afghanistan                                             11
# Niger                                                   11
# Gambia                                                  11
# Bhutan                                                  11
# Fiji                                                    11
# Guinea-Bissau                                           11
# Guinea                                                  11
# Mauritania                                              11
# Netherlands                                             11
# Sri Lanka                                               11
# Kenya                                                   11
# Republic of Congo                                       11
# Uzbekistan                                              11
# Panama                                                  11
# India                                                   11
# Uganda                                                  11
# Tajikistan                                              11
# Eswatini                                                11
# Peru                                                    11
# Eritrea                                                 11
# Central African Republic                                11
# Morocco                                                 11
# Greece                                                  11
# Djibouti                                                11
# Georgia                                                 11
# Turkmenistan                                            11
# Comoros                                                 11
# Pakistan                                                11
# Lesotho                                                 11
# Thailand                                                11
# Malawi                                                  11
# Ghana                                                   11
# Suriname                                                11
# Sudan                                                   11
# Liberia                                                 11
# Nigeria                                                 11
# Cote d'Ivoire                                           11
# Guyana                                                  11
# Ecuador                                                 11
# Rwanda                                                  11
# United Republic of Tanzania                             11
# Myanmar                                                 11
# Kyrgyzstan                                              11
# Zambia                                                  11
# Ethiopia                                                11
# Algeria                                                 11
# Angola                                                  11
# Armenia                                                 11
# Samoa                                                    7
# Sao Tome and Principe                                    6
# Antigua and Barbuda                                      3
# Democratic Republic of Congo                             3
# Federated States of Micronesia                           3
# Montenegro                                               3
# Saint Lucia                                              3
# Maldives                                                 3
# Saint Vincent and the Grenadines                         3
# Dominica                                                 2
# Name: count, dtype: int64

# %%
# Check countries with missing counts
df[df['Country'].isin(['Samoa', 'Sao Tome and Principe', 'Antigua and Barbuda', 'Democratic Republic of Congo', 'Federated States of Micronesia', 'Montenegro', 'Saint Lucia', 'Maldives', 'Saint Vincent and the Grenadines', 'Dominica'])].sort_values(by=['Country', 'Year'])
# Out:
#                                Country  Year    WRI  Exposure  Vulnerability  \
# 1041               Antigua and Barbuda  2019  30.80     69.95          44.03
# 1223               Antigua and Barbuda  2020  27.44     68.92          39.82
# 692                Antigua and Barbuda  2021  27.28     67.73          40.28
# 1095      Democratic Republic of Congo  2019   8.80     11.95          73.63
# 1275      Democratic Republic of Congo  2020   8.77     11.80          74.28
# 743       Democratic Republic of Congo  2021   8.78     11.86          74.04
# 1222                          Dominica  2020  28.47     62.74          45.38
# 691                           Dominica  2021  27.42     61.74          44.41
# 1111    Federated States of Micronesia  2019   7.52     14.72          51.05
# 1292    Federated States of Micronesia  2020   7.59     14.95          50.77
# 768     Federated States of Micronesia  2021   7.11     14.03          50.71
# 1208                          Maldives  2019   2.08      4.92          42.18
# 1390                          Maldives  2020   2.12      4.77          44.40
# 862                           Maldives  2021   1.69      4.18          40.39
# 1127                        Montenegro  2019   6.62     17.80          37.18
# 1301                        Montenegro  2020   6.93     18.12          38.24
# 773                         Montenegro  2021   6.75     17.80          37.92
# 1162                       Saint Lucia  2019   4.52     10.24          44.15
# 1342                       Saint Lucia  2020   4.70     10.24          45.88
# 811                        Saint Lucia  2021   4.52      9.83          45.96
# 1217  Saint Vincent and the Grenadines  2019   0.80      1.88          42.86
# 1398  Saint Vincent and the Grenadines  2020   0.81      1.85          43.79
# 866   Saint Vincent and the Grenadines  2021   0.70      1.62          43.00
# 62                               Samoa  2011   7.88     14.95          52.69
# 1519                             Samoa  2012   4.51      9.10          49.58
# 292                              Samoa  2013   4.51      9.10          49.58
# 1649                             Samoa  2018   6.71     14.12          47.53
# 1133                             Samoa  2019   6.19     13.04          47.50
# 1317                             Samoa  2020   5.87     12.19          48.13
# 796                              Samoa  2021   5.54     11.46          48.32
# 130              Sao Tome and Principe  2011   3.73      6.28          59.45
# 1544             Sao Tome and Principe  2012   3.40      5.81          58.55
# 316              Sao Tome and Principe  2013   3.35      5.81          57.71
# 1201             Sao Tome and Principe  2019   2.49      4.53          54.93
# 1382             Sao Tome and Principe  2020   2.58      4.55          56.74
# 850              Sao Tome and Principe  2021   2.57      4.54          56.60
#
#       Susceptibility  Lack of Coping Capacities  Lack of Adaptive Capacities  \
# 1041           23.38                      76.65                        32.05
# 1223           23.33                      63.31                        32.83
# 692            23.80                      64.41                        32.62
# 1095           67.13                      92.56                        61.21
# 1275           67.78                      92.95                        62.12
# 743            67.76                      92.80                        61.55
# 1222           26.12                      71.21                        38.82
# 691            23.42                      71.13                        38.67
# 1111           34.11                      72.11                        46.93
# 1292           31.79                      72.13                        48.39
# 768            31.04                      72.21                        48.89
# 1208           19.58                      70.65                        36.29
# 1390           17.45                      76.51                        39.23
# 862            15.59                      65.82                        39.76
# 1127           17.49                      67.97                        26.06
# 1301           18.71                      68.42                        27.59
# 773            18.57                      68.20                        26.99
# 1162           21.72                      75.19                        35.55
# 1342           24.22                      75.67                        37.74
# 811            23.68                      74.26                        39.95
# 1217           27.70                      70.92                        29.95
# 1398           28.20                      71.77                        31.39
# 866            28.16                      69.86                        30.97
# 62             30.49                      79.85                        47.73
# 1519           27.91                      73.83                        47.00
# 292            27.77                      73.12                        47.84
# 1649           26.28                      72.11                        44.19
# 1133           25.52                      79.70                        37.27
# 1317           25.40                      79.66                        39.33
# 796            25.56                      79.83                        39.56
# 130            45.58                      80.26                        52.52
# 1544           46.17                      77.52                        51.96
# 316            46.09                      75.04                        51.99
# 1201           43.21                      76.00                        45.58
# 1382           46.44                      76.64                        47.13
# 850            45.67                      77.23                        46.90
#
#      WRI Category Exposure Category Vulnerability Category  \
# 1041    Very High         Very High                 Medium
# 1223    Very High         Very High                    Low
# 692     Very High         Very High                    Low
# 1095         High               Low              Very High
# 1275         High               Low              Very High
# 743          High               Low              Very High
# 1222    Very High         Very High                 Medium
# 691     Very High         Very High                 Medium
# 1111         High            Medium                   High
# 1292         High              High                   High
# 768        Medium            Medium                   High
# 1208     Very Low          Very Low                 Medium
# 1390     Very Low          Very Low                 Medium
# 862      Very Low          Very Low                    Low
# 1127       Medium              High                    Low
# 1301       Medium              High                    Low
# 773        Medium              High                    Low
# 1162          Low               Low                 Medium
# 1342          Low               Low                 Medium
# 811           Low               Low                 Medium
# 1217     Very Low          Very Low                 Medium
# 1398     Very Low          Very Low                 Medium
# 866      Very Low          Very Low                 Medium
# 62           High              High                 Medium
# 1519          Low          Very Low                 Medium
# 292           Low          Very Low                 Medium
# 1649       Medium            Medium                 Medium
# 1133       Medium            Medium                 Medium
# 1317       Medium            Medium                   High
# 796           Low               Low                 Medium
# 130           Low          Very Low                   High
# 1544     Very Low          Very Low                   High
# 316      Very Low          Very Low                   High
# 1201     Very Low          Very Low                   High
# 1382     Very Low          Very Low                   High
# 850      Very Low          Very Low                   High
#
#      Susceptibility Category
# 1041                  Medium
# 1223                  Medium
# 692                   Medium
# 1095               Very High
# 1275               Very High
# 743                Very High
# 1222                  Medium
# 691                   Medium
# 1111                    High
# 1292                    High
# 768                     High
# 1208                     Low
# 1390                     Low
# 862                 Very Low
# 1127                     Low
# 1301                     Low
# 773                      Low
# 1162                  Medium
# 1342                  Medium
# 811                   Medium
# 1217                  Medium
# 1398                    High
# 866                   Medium
# 62                    Medium
# 1519                  Medium
# 292                   Medium
# 1649                  Medium
# 1133                  Medium
# 1317                  Medium
# 796                   Medium
# 130                     High
# 1544                    High
# 316                     High
# 1201                    High
# 1382               Very High
# 850                Very High

# %% [markdown]
# #### <mark>Note:</mark>
#
# A value of 11 is expected, as the dataset should cover entries per country for the years 2011-2021. Countries with a frequency lower than 11 were not part of the WorldRiskReport in some years for various reasons.
# The values for the missing years were reworked and could be obtained from the trend data set at a later stage of the analysis, if necessary. However, the revised data take into account changes, adjustments or updates in the source data. Accordingly, there is a possibility of discrepancies between the trend dataset and the individual datasets. Therefore, imputations should be handled with care.

# %% [markdown]
# ## 3.4 Mixed-type values

# %% [markdown]
# #### Check for mixed-type values

# %%
# Check for mixed types
for col in df.columns.tolist():
  mixed = (df[[col]].map(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len(df[mixed]) > 0:
    print(col)
else:
    print('No mixed-type columns.')
# Out:
# No mixed-type columns.

# %% [markdown]
# #### Change data types

# %%
# Check the metadata of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      1917 non-null   object
#  1   Year                         1917 non-null   int64
#  2   WRI                          1917 non-null   float64
#  3   Exposure                     1917 non-null   float64
#  4   Vulnerability                1917 non-null   float64
#  5   Susceptibility               1917 non-null   float64
#  6   Lack of Coping Capacities    1917 non-null   float64
#  7   Lack of Adaptive Capacities  1917 non-null   float64
#  8   WRI Category                 1917 non-null   object
#  9   Exposure Category            1917 non-null   object
#  10  Vulnerability Category       1917 non-null   object
#  11  Susceptibility Category      1917 non-null   object
# dtypes: float64(6), int64(1), object(5)
# memory usage: 179.8+ KB

# %%
# Change data type of 'Year' from integer to string to exclude it from statistics
df['Year'] = df['Year'].astype(str)

# %%
# Check the data types
df.dtypes
# Out:
# Country                         object
# Year                            object
# WRI                            float64
# Exposure                       float64
# Vulnerability                  float64
# Susceptibility                 float64
# Lack of Coping Capacities      float64
# Lack of Adaptive Capacities    float64
# WRI Category                    object
# Exposure Category               object
# Vulnerability Category          object
# Susceptibility Category         object
# dtype: object

# %%
# Check the output
df.head()
# Out:
#            Country  Year    WRI  Exposure  Vulnerability  Susceptibility  \
# 0          Vanuatu  2011  32.00     56.33          56.81           37.14
# 1            Tonga  2011  29.08     56.04          51.90           28.94
# 2      Philippines  2011  24.32     45.09          53.93           34.99
# 3  Solomon Islands  2011  23.51     36.40          64.60           44.11
# 4        Guatemala  2011  20.88     38.42          54.35           35.36
#
#    Lack of Coping Capacities  Lack of Adaptive Capacities WRI Category  \
# 0                      79.34                        53.96    Very High
# 1                      81.80                        44.97    Very High
# 2                      82.78                        44.01    Very High
# 3                      85.95                        63.74    Very High
# 4                      77.83                        49.87    Very High
#
#   Exposure Category Vulnerability Category Susceptibility Category
# 0         Very High                   High                    High
# 1         Very High                 Medium                  Medium
# 2         Very High                   High                    High
# 3         Very High              Very High                    High
# 4         Very High                   High                    High

# %% [markdown]
# ## 3.5 Duplicates

# %%
# Find full duplicates
df_dups = df[df.duplicated()]

df_dups
# Out:
# Empty DataFrame
# Columns: [Country, Year, WRI, Exposure, Vulnerability, Susceptibility, Lack of Coping Capacities, Lack of Adaptive Capacities, WRI Category, Exposure Category, Vulnerability Category, Susceptibility Category]
# Index: []

# %% [markdown]
# #### <mark>Note:</mark>
#
# No duplicates found.

# %% [markdown]
# # 4. Descriptive statistics

# %%
# Print descriptive statistics
df.describe()
# Out:
#                WRI     Exposure  Vulnerability  Susceptibility  \
# count  1917.000000  1917.000000    1917.000000     1917.000000
# mean      7.546390    15.380026      48.084371       30.722613
# std       5.551136    10.234068      13.819766       15.667353
# min       0.020000     0.050000      20.970000        8.260000
# 25%       3.740000    10.160000      37.040000       17.780000
# 50%       6.520000    12.760000      47.100000       25.370000
# 75%       9.370000    16.450000      60.060000       42.610000
# max      56.710000    99.880000      76.470000       70.830000
#
#        Lack of Coping Capacities  Lack of Adaptive Capacities
# count                1917.000000                  1917.000000
# mean                   70.446093                    43.084512
# std                    15.022557                    13.550165
# min                    35.160000                    11.160000
# 25%                    59.330000                    33.170000
# 50%                    74.230000                    43.070000
# 75%                    83.000000                    53.060000
# max                    94.360000                    76.110000

# %% [markdown]
# #### <mark>Note:</mark>
#
# **Variable ranges:**
# * WRI scores range from 0.02 to 56.71, indicating a wide range of variability.
#
# **Central tendency:**
# * Mean scores for WRI, exposure, vulnerability, susceptibility, lack of coping skills, and lack of adaptive skills hover around 7.55, 15.38, 48.08, 30.72, 70.45, and 43.08, respectively, reflecting typical values.
#
# **Variability:**
# * WRI's standard deviation is about 5.55, indicating moderate variability.

# %% [markdown]
# # 5. Exporting data

# %%
# Confirm the shape of the dataset
df.shape
# Out:
# (1917, 12)

# %%
# Export df as "WRI_clean.csv"
df.to_csv(os.path.join(path, '02_Data', 'Prepared_data', 'WRI_clean.csv'), index = False)
